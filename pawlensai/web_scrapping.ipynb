# %%
# !pip install roboflow

# %%
from roboflow import Roboflow
rf = Roboflow(api_key="wK2F3gNSb8ERBf0Ox5ki")
project = rf.workspace("errol-iylrb").project("dogs-skin-disease-fxh4x-j8pqs")
version = project.version(1)
dataset = version.download("folder")
# Out:
# loading Roboflow workspace...
# loading Roboflow project...
# ...
# Extracting Dataset Version Zip to Dogs-skin-disease-1 in folder:: 100%|██████████| 4256/4256 [00:00<00:00, 8758.77it/s]
